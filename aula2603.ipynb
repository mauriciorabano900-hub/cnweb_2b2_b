# %% [markdown]
# <a href="https://colab.research.google.com/github/mauriciorabano900-hub/cnweb_2b2_b/blob/main/aula2603.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exemplo de serviço

# %%
def soma(a, b):
  return (a+b)

# %%
soma(8, 45)
# Out:
# 53

# %% [markdown]
# # Sistema de equações

# %%
import math

def eq2grau(a, b, c):
  delta = b**2 - 4*a*c

  if(delta < 0):
    return 'equação sem solução'
  else:
    x1 = (-b + math.sqrt(delta)) / (2*a)
    x2 = (-b - math.sqrt(delta)) / (2*a)
    return x1, x2

# %%
print(eq2grau(1, -3, 2))
# Out:
# (2.0, 1.0)
